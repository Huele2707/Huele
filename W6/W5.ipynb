# %% [markdown]
# ## Thực hành tuần 5

# %%
import pandas as pd
import numpy as np
import openml

# %%
for i in openml.datasets.list_datasets(output_format="dataframe")['name'].unique():
    print(i)
# Out:
# anneal
# kr-vs-kp
# labor
# arrhythmia
# letter
# audiology
# liver-disorders
# autos
# lymph
# balance-scale
# mfeat-factors
# breast-cancer
# mfeat-fourier
# breast-w
# mfeat-karhunen
# mfeat-morphological
# mfeat-pixel
# mfeat-zernike
# cmc
# mushroom
# colic
# nursery
# optdigits
# credit-approval
# page-blocks
# credit-g
# pendigits
# postoperative-patient-data
# dermatology
# segment
# diabetes
# sick
# ecoli
# sonar
# glass
# soybean
# haberman
# spambase
# splice
# tae
# heart-c
# tic-tac-toe
# heart-h
# trains
# heart-statlog
# vehicle
# hepatitis
# vote
# hypothyroid
# ionosphere
# waveform-5000
# iris
# zoo
# BNG(anneal,nominal,1000000)
# BNG(anneal.ORIG,nominal,1000000)
# BNG(kr-vs-kp)
# BNG(labor,nominal,1000000)
# BNG(letter,nominal,1000000)
# BNG(autos,nominal,1000000)
# BNG(lymph,nominal,1000000)
# BNG(breast-cancer,nominal,1000000)
# BNG(mfeat-fourier,nominal,1000000)
# BNG(mfeat-karhunen,nominal,1000000)
# BNG(bridges_version1,nominal,1000000)
# ...

# %% [markdown]
# ## 1. Load dữ liệu từ openml

# %%
dataset = openml.datasets.get_dataset(dataset_id = 'vehicle_reproduced')

# %%
dataset
# Out:
# OpenML Dataset
# ...
# Name..........: vehicle_reproduced
# Version.......: 1
# Format........: arff
# Upload Date...: 2022-07-09 18:31:05
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/22103278/vehicle_reproduced.arff
# OpenML URL....: https://www.openml.org/d/44153
# # of features.: 19
# # of instances: 846

# %% [markdown]
# ## 2 Tìm hiểu về tập dữ liệu

# %%
X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute, dataset_format='array')

# %%
X.shape
# Out:
# (846, 18)

# %%
np.unique(y)
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ## 3. KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=3)

neigh.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)
