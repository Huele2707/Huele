# %%
# !pip install requests
# !pip install selenium
# !pip install pandas
# !pip install webdriver_manager

# %%
import requests
import os
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import sqlite3

# %%
url='https://api2.binance.com/api/v3/ticker/24hr'

# %%
requests = requests.get(url)

# %%
if requests.status_code == 200:
    print("Truy cập thành công")
else:
    print(requests.status_code)
# Out:
# Truy cập thành công

# %%
data = requests.json()
print(data)
# Out:
# [{'symbol': 'ETHBTC', 'priceChange': '-0.00471100', 'priceChangePercent': '-5.749', 'weightedAvgPrice': '0.07911994', 'prevClosePrice': '0.08195000', 'lastPrice': '0.07724000', 'lastQty': '0.55710000', 'bidPrice': '0.07723900', 'bidQty': '5.39890000', 'askPrice': '0.07724000', 'askQty': '6.26580000', 'openPrice': '0.08195100', 'highPrice': '0.08196000', 'lowPrice': '0.07682700', 'volume': '130897.71830000', 'quoteVolume': '10356.61932491', 'openTime': 1662919798049, 'closeTime': 1663006198049, 'firstId': 371846972, 'lastId': 372244976, 'count': 398005}, {'symbol': 'LTCBTC', 'priceChange': '-0.00015900', 'priceChangePercent': '-5.485', 'weightedAvgPrice': '0.00280930', 'prevClosePrice': '0.00289900', 'lastPrice': '0.00274000', 'lastQty': '0.34200000', 'bidPrice': '0.00273900', 'bidQty': '79.58400000', 'askPrice': '0.00274000', 'askQty': '22.50800000', 'openPrice': '0.00289900', 'highPrice': '0.00291600', 'lowPrice': '0.00272400', 'volume': '106667.55800000', 'quoteVolume': '299.661520
# ...

# %%
data[0].keys()
# Out:
# dict_keys(['symbol', 'priceChange', 'priceChangePercent', 'weightedAvgPrice', 'prevClosePrice', 'lastPrice', 'lastQty', 'bidPrice', 'bidQty', 'askPrice', 'askQty', 'openPrice', 'highPrice', 'lowPrice', 'volume', 'quoteVolume', 'openTime', 'closeTime', 'firstId', 'lastId', 'count'])

# %%
data[0]
# Out:
# {'symbol': 'ETHBTC',
#  'priceChange': '-0.00471100',
#  'priceChangePercent': '-5.749',
#  'weightedAvgPrice': '0.07911994',
#  'prevClosePrice': '0.08195000',
#  'lastPrice': '0.07724000',
#  'lastQty': '0.55710000',
#  'bidPrice': '0.07723900',
#  'bidQty': '5.39890000',
#  'askPrice': '0.07724000',
#  'askQty': '6.26580000',
#  'openPrice': '0.08195100',
#  'highPrice': '0.08196000',
#  'lowPrice': '0.07682700',
#  'volume': '130897.71830000',
#  'quoteVolume': '10356.61932491',
#  'openTime': 1662919798049,
#  'closeTime': 1663006198049,
#  'firstId': 371846972,
#  'lastId': 372244976,
#  'count': 398005}

# %%
df = pd.DataFrame(data)
df
# Out:
#         symbol  priceChange priceChangePercent weightedAvgPrice  \
# 0       ETHBTC  -0.00471100             -5.749       0.07911994
# 1       LTCBTC  -0.00015900             -5.485       0.00280930
# 2       BNBBTC  -0.00052300             -3.836       0.01340459
# 3       NEOBTC  -0.00001200             -2.637       0.00045244
# 4      QTUMETH   0.00003800              2.025       0.00190085
# ...        ...          ...                ...              ...
# 2092  LOOMBUSD   0.03203000             36.564       0.12363595
# 2093   SNMBUSD   0.42700000            110.679       0.64132779
# 2094   AMBBUSD   0.01188000             47.634       0.03262652
# 2095  LUNCUSDT  -0.00006802            -16.836       0.00037166
# 2096   PHBBUSD   1.12970000            140.231       1.36381871
#
#      prevClosePrice   lastPrice           lastQty    bidPrice  \
# 0        0.08195000  0.07724000        0.55710000  0.07723900
# 1        0.00289900  0.00274000        0.34200000  0.00273900
# ...

# %%
df.to_csv('bai1.csv',index=False)

# %%
#Hiển thị 10 dòng đầu tiên
df.head(10)
# Out:
#     symbol  priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0   ETHBTC  -0.00471100             -5.749       0.07911994     0.08195000
# 1   LTCBTC  -0.00015900             -5.485       0.00280930     0.00289900
# 2   BNBBTC  -0.00052300             -3.836       0.01340459     0.01363300
# 3   NEOBTC  -0.00001200             -2.637       0.00045244     0.00045600
# 4  QTUMETH   0.00003800              2.025       0.00190085     0.00187300
# 5   EOSETH  -0.00000900             -0.919       0.00098094     0.00097900
# 6   SNTETH   0.00000297             17.358       0.00002242     0.00001710
# 7   BNTETH   0.00000700              2.465       0.00029084     0.00028500
# 8   BCCBTC   0.00000000              0.000       0.00000000     0.07908100
# 9   GASBTC  -0.00000490             -4.184       0.00011427     0.00011690
#
#     lastPrice         lastQty    bidPrice         bidQty    askPrice  ...  \
# ...

# %% [markdown]
# # Bài 3

# %%
path = 'C:/Users/Admin/Documents/Nhập môn khoa học dữ liệu' 

con = sqlite3.connect('DS_database') 

df = pd.read_csv('bai1.csv')

df.to_sql('BAI3',con)

data = pd.read_sql('SELECT * FROM BAI3', con)
data
# Out:
#       index    symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0         0    ETHBTC    -0.004711              -5.749          0.079120
# 1         1    LTCBTC    -0.000159              -5.485          0.002809
# 2         2    BNBBTC    -0.000523              -3.836          0.013405
# 3         3    NEOBTC    -0.000012              -2.637          0.000452
# 4         4   QTUMETH     0.000038               2.025          0.001901
# ...     ...       ...          ...                 ...               ...
# 2092   2092  LOOMBUSD     0.032030              36.564          0.123636
# 2093   2093   SNMBUSD     0.427000             110.679          0.641328
# 2094   2094   AMBBUSD     0.011880              47.634          0.032627
# 2095   2095  LUNCUSDT    -0.000068             -16.836          0.000372
# 2096   2096   PHBBUSD     1.129700             140.231          1.363819
#
#       prevClosePrice  lastPrice       lastQty  bidPrice       bidQty  ...  \
# ...

# %%
# Lấy ra càng dòng có 'prevClosePrice'>0.008
data = pd.read_sql('SELECT * FROM BAI3 where prevClosePrice>0.008', con)
data
# Out:
#       index    symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0         0    ETHBTC    -0.004711              -5.749          0.079120
# 1         2    BNBBTC    -0.000523              -3.836          0.013405
# 2         8    BCCBTC     0.000000               0.000          0.000000
# 3        10    BNBETH     0.003400               2.044          0.169665
# 4        11   BTCUSDT   679.580000               3.144      21986.247200
# ...     ...       ...          ...                 ...               ...
# 1212   2091  BETHBUSD   -44.540000              -2.625       1665.835076
# 1213   2092  LOOMBUSD     0.032030              36.564          0.123636
# 1214   2093   SNMBUSD     0.427000             110.679          0.641328
# 1215   2094   AMBBUSD     0.011880              47.634          0.032627
# 1216   2096   PHBBUSD     1.129700             140.231          1.363819
#
#       prevClosePrice    lastPrice     lastQty      bidPrice      bidQty  ...  \
# ...

# %%
# Tính tổng cột 'lastPrice'
data = pd.read_sql('SELECT SUM(lastPrice) FROM BAI3', con)
data
# Out:
#    SUM(lastPrice)
# 0    3.662134e+08
