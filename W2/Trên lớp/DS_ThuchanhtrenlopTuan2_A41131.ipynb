# %%
# !pip install requests
# !pip install selenium
# !pip install pandas
# !pip install webdriver_manager

# %%
import requests
import os
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import sqlite3

# %%
# %cd 'C:\Users\sv\Documents\A41131'
# Out:
# [WinError 123] The filename, directory name, or volume label syntax is incorrect: "'C:\\Users\\sv\\Documents\\A41131'"
# C:\Users\sv\Documents\A41131

# %%
data = pd.read_csv("./data.csv")
data.head(5)
# Out:
#          API                                Description    Auth  HTTPS Cors  \
# 0  AdoptAPet          Resource to help get pets adopted  apiKey   True  yes
# 1    Axolotl   Collection of axolotl pictures and facts     NaN   True   no
# 2  Cat Facts                            Daily cat facts     NaN   True   no
# 3     Cataas  Cat as a service (cats pictures and gifs)     NaN   True   no
# 4       Cats               Pictures of cats from Tumblr  apiKey   True   no
#
#                                                 Link Category
# 0  https://www.adoptapet.com/public/apis/pet_list...  Animals
# 1                 https://theaxolotlapi.netlify.app/  Animals
# 2         https://alexwohlbruck.github.io/cat-facts/  Animals
# 3                                https://cataas.com/  Animals
# 4                        https://docs.thecatapi.com/  Animals

# %%
data['API']
# Out:
# 0             AdoptAPet
# 1               Axolotl
# 2             Cat Facts
# 3                Cataas
# 4                  Cats
#              ...
# 1420    Visual Crossing
# 1421        weather-api
# 1422         WeatherAPI
# 1423         Weatherbit
# 1424     Yandex.Weather
# Name: API, Length: 1425, dtype: object

# %%
data['HTTPS']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1420    True
# 1421    True
# 1422    True
# 1423    True
# 1424    True
# Name: HTTPS, Length: 1425, dtype: bool

# %%
data.loc[0:5,['API','Auth']]
#hiện từ 0->5. 2 tên cột cần hiện
# Out:
#          API    Auth
# 0  AdoptAPet  apiKey
# 1    Axolotl     NaN
# 2  Cat Facts     NaN
# 3     Cataas     NaN
# 4       Cats  apiKey
# 5  Dog Facts     NaN

# %%
data.iloc[0:5,[0,2]]
# iloc chi so. hàng từ 1 đén 4, cột từ 0 đến 1
# Out:
#          API    Auth
# 0  AdoptAPet  apiKey
# 1    Axolotl     NaN
# 2  Cat Facts     NaN
# 3     Cataas     NaN
# 4       Cats  apiKey

# %% [markdown]
# ## xóa dòng, cột

# %%
# asix = 1 là cột. = 0 là dòng 
data.drop(columns = ['API','HTTPS'])
# Out:
#                                             Description    Auth     Cors  \
# 0                     Resource to help get pets adopted  apiKey      yes
# 1              Collection of axolotl pictures and facts     NaN       no
# 2                                       Daily cat facts     NaN       no
# 3             Cat as a service (cats pictures and gifs)     NaN       no
# 4                          Pictures of cats from Tumblr  apiKey       no
# ...                                                 ...     ...      ...
# 1420        Global historical and weather forecast data  apiKey      yes
# 1421            A RESTful free API to check the weather     NaN       no
# 1422  Weather API with other stuff like Astronomy an...  apiKey      yes
# 1423                                            Weather  apiKey  unknown
# 1424   Assesses weather condition in specific locations  apiKey       no
#
#                                                    Link Category
# ...

# %%
#xóa cột Category
data.drop(columns = ['Category'], axis = 1)
# Out:
#                   API                                        Description  \
# 0           AdoptAPet                  Resource to help get pets adopted
# 1             Axolotl           Collection of axolotl pictures and facts
# 2           Cat Facts                                    Daily cat facts
# 3              Cataas          Cat as a service (cats pictures and gifs)
# 4                Cats                       Pictures of cats from Tumblr
# ...               ...                                                ...
# 1420  Visual Crossing        Global historical and weather forecast data
# 1421      weather-api            A RESTful free API to check the weather
# 1422       WeatherAPI  Weather API with other stuff like Astronomy an...
# 1423       Weatherbit                                            Weather
# 1424   Yandex.Weather   Assesses weather condition in specific locations
#
#         Auth  HTTPS     Cors  \
# 0     apiKey   True      yes
# ...

# %%
data.columns
# biết danh sách các cột trong file
# Out:
# Index(['API', 'Description', 'Auth', 'HTTPS', 'Cors', 'Link', 'Category'], dtype='object')

# %%
#Kiểm tra bnh cái bị missing-value trong cột 
data.isnull().sum()
# Out:
# API              0
# Description      0
# Auth           669
# HTTPS            0
# Cors             0
# Link             0
# Category         0
# dtype: int64

# %%
data['API'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1420    False
# 1421    False
# 1422    False
# 1423    False
# 1424    False
# Name: API, Length: 1425, dtype: bool
